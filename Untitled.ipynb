# %%
# tabular data manipulation
import numpy as np
import pandas as pd
# datetime utilities
from datetime import timedelta, datetime
# visualization
import matplotlib.pyplot as plt

# no yelling in the library
import warnings
warnings.filterwarnings("ignore")

# our acquire script
import acquire

# %%
stores= acquire.stores_df()
stores

# %%
items= acquire.items_df()
items

# %%
sales_df = acquire.sales_csv()
sales_df

# %%
df= acquire.all_store_data()
df
# Out:
#         Unnamed: 0_x  item  sale_amount                      sale_date  \
# 0                  0     1         13.0  Tue, 01 Jan 2013 00:00:00 GMT
# 1                  1     1         11.0  Wed, 02 Jan 2013 00:00:00 GMT
# 2                  2     1         14.0  Thu, 03 Jan 2013 00:00:00 GMT
# 3                  3     1         13.0  Fri, 04 Jan 2013 00:00:00 GMT
# 4                  4     1         10.0  Sat, 05 Jan 2013 00:00:00 GMT
# ...              ...   ...          ...                            ...
# 912995        912995    50         63.0  Wed, 27 Dec 2017 00:00:00 GMT
# 912996        912996    50         59.0  Thu, 28 Dec 2017 00:00:00 GMT
# 912997        912997    50         74.0  Fri, 29 Dec 2017 00:00:00 GMT
# 912998        912998    50         62.0  Sat, 30 Dec 2017 00:00:00 GMT
# 912999        912999    50         82.0  Sun, 31 Dec 2017 00:00:00 GMT
#
#         sale_id  store  Unnamed: 0_y           store_address   store_city  \
# 0             1      1             0  12125 Alamo Ranch Pkwy  San Antonio
# 1             2      1             0  12125 Alamo Ranch Pkwy  San Antonio
# 2             3      1             0  12125 Alamo Ranch Pkwy  San Antonio
# 3             4      1             0  12125 Alamo Ranch Pkwy  San Antonio
# 4             5      1             0  12125 Alamo Ranch Pkwy  San Antonio
# ...         ...    ...           ...                     ...          ...
# 912995   912996     10             9    8503 NW Military Hwy  San Antonio
# 912996   912997     10             9    8503 NW Military Hwy  San Antonio
# 912997   912998     10             9    8503 NW Military Hwy  San Antonio
# 912998   912999     10             9    8503 NW Military Hwy  San Antonio
# 912999   913000     10             9    8503 NW Military Hwy  San Antonio
#
#         store_id store_state  store_zipcode  Unnamed: 0.1 item_brand  item_id  \
# 0              1          TX          78253             0   Riceland        1
# 1              1          TX          78253             0   Riceland        1
# 2              1          TX          78253             0   Riceland        1
# 3              1          TX          78253             0   Riceland        1
# 4              1          TX          78253             0   Riceland        1
# ...          ...         ...            ...           ...        ...      ...
# 912995        10          TX          78231            49     Choice       50
# 912996        10          TX          78231            49     Choice       50
# 912997        10          TX          78231            49     Choice       50
# 912998        10          TX          78231            49     Choice       50
# 912999        10          TX          78231            49     Choice       50
#
#                                                 item_name  item_price  \
# 0                          Riceland American Jazmine Rice        0.84
# 1                          Riceland American Jazmine Rice        0.84
# 2                          Riceland American Jazmine Rice        0.84
# 3                          Riceland American Jazmine Rice        0.84
# 4                          Riceland American Jazmine Rice        0.84
# ...                                                   ...         ...
# 912995  Choice Organic Teas Black Tea Classic Black - ...        5.20
# 912996  Choice Organic Teas Black Tea Classic Black - ...        5.20
# 912997  Choice Organic Teas Black Tea Classic Black - ...        5.20
# 912998  Choice Organic Teas Black Tea Classic Black - ...        5.20
# 912999  Choice Organic Teas Black Tea Classic Black - ...        5.20
#
#          item_upc12   item_upc14
# 0       35200264013  35200264013
# 1       35200264013  35200264013
# 2       35200264013  35200264013
# 3       35200264013  35200264013
# 4       35200264013  35200264013
# ...             ...          ...
# 912995  47445919221  47445919221
# 912996  47445919221  47445919221
# 912997  47445919221  47445919221
# 912998  47445919221  47445919221
# 912999  47445919221  47445919221
#
# [913000 rows x 19 columns]
